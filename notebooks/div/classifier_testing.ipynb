# %%
import numpy as np

from scripts.data_filter import filter_dataframe
from scripts.data_loader import load_dataframe
from scripts.data_writer import save_experiment_result
from scripts.utils import NETWORK_TYPE

filename = "5G_data_2023.mat"

# Series of random seeds for reproducability
random_seeds = np.loadtxt('../../data/random_seeds.csv', dtype=int)

# load the dataframe from saved file or 'raw' matlab file
df = load_dataframe(filename, NETWORK_TYPE._5G)

# # Drop unused columns to save space
matrix_cols_to_drop = ['toa_pps', 'toa_cir', 'toa_cov', 'campaign_id']
df['measurements_matrix'] = df['measurements_matrix'].apply(
    lambda x: x.drop(columns=matrix_cols_to_drop)
)

selected_campaigns = list(range(1, 40))
# Data filtering
df = filter_dataframe(
    df=df,
    include_columns=['pci', 'beam_index', 'nr_arfcn', 'operator_id', 'rsrq', 'sinr', 'rssi', 'rsrp'],
    campaigns=selected_campaigns,
)
# Out:
# Loaded dataframe from .h5 file: /Users/andreres/Documents/UIO/master/thesis/dev/5G_localization/data/dataframe_cache/5G_data_2023.h5
# /Users/andreres/Documents/UIO/master/thesis/dev/5G_localization/scripts/data_filter.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["measurements_matrix"] = df["measurements_matrix"].apply(

# %%
from scripts.utils import *
from scripts.clustering import *
from sklearn.metrics import accuracy_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score
import pandas as pd


def evaluate_model(rf_model, X_test, y_test):
    # Predict the test set
    y_pred = rf_model.predict(X_test)

    # Calculate overall metrics
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    cv_scores = cross_val_score(rf_model, X_test, y_test, cv=5)
    mean_cv_score = cv_scores.mean()

    # Create a dictionary of metrics
    metrics = {
        'accuracy': accuracy,
        'recall': recall,
        'f1_score': f1,
        'mean_cv_score': mean_cv_score
    }

    return metrics


def run_test(df: pd.DataFrame, n_clusters: int, rf_param: RF_PARAM_5G, random: int):
    kmeans, cluster_labels = train_kmeans(
        df,
        n_clusters=n_clusters,
        rf_param=rf_param,
        random_state=random
    )

    df['cluster'] = cluster_labels
    pcis = extract_unique_npcis(df['measurements_matrix'])

    df_tp, df_rp = dataset_tp_rp_split(df, 0.3, random)

    rf_model = train_random_forest(
        df=df_rp,
        unique_npcis=pcis,
        rf_param=rf_param,
        n_estimators=100,
        random_state=random
    )

    tp_features, _ = create_point_matrix(df_tp, pcis, rf_param)
    df_tp['predicted_cluster'] = rf_model.predict(tp_features)

    # Prepare test data
    y_test = df_tp['cluster']
    X_test = tp_features

    # Evaluate model and return metrics
    metrics = evaluate_model(rf_model, X_test, y_test)
    return metrics


# params = [RF_PARAM_5G.RSRQ, RF_PARAM_5G.RSSI, RF_PARAM_5G.RSRP, RF_PARAM_5G.SINR]
params = [RF_PARAM_5G.RSRQ]
cluster_range = range(2, 15)
n_runs = 1
data = []

for param in params:
    for n_clusters in cluster_range:
        for run in range(n_runs):
            print(f"\rParameter: {param}, n_clusters: {n_clusters}")
            res = run_test(df=df, n_clusters=n_clusters, rf_param=param.RSRQ, random=random_seeds[n_clusters + run])
            # Add additional information to the result
            res['param'] = param
            res['n_clusters'] = n_clusters
            res['run'] = run
            data.append(res)

# Create a DataFrame from the collected data
res_df = pd.DataFrame(data)

config = {
    'params': params,
    cluster_range: list(cluster_range),
    n_runs: n_runs,
}
data = {
    data: res_df
}

save_experiment_result('random_forest_experiment', config, data)
# Out:
# Parameter: RF_PARAM_5G.RSRQ, n_clusters: 2
# Parameter: RF_PARAM_5G.RSRQ, n_clusters: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 73
#      71 for run in range(n_runs):
#      72     print(f"\rParameter: {param}, n_clusters: {n_clusters}")
# ---> 73     res = run_test(df=df, n_clusters=n_clusters, rf_param=param.RSRQ, random=random_seeds[n_clusters + run])
#      74     # Add additional information to the result
#      75     res['param'] = param
#
# Cell In[6], line 31, in run_test(df, n_clusters, rf_param, random)
#      30 def run_test(df: pd.DataFrame, n_clusters: int, rf_param: RF_PARAM_5G, random: int):
# ---> 31     kmeans, cluster_labels = train_kmeans(
#      32         df,
#      33         n_clusters=n_clusters,
#      34         rf_param=rf_param,
#      35         random_state=random
#      36     )
#      38     df['cluster'] = cluster_labels
#      39     pcis = extract_unique_npcis(df['measurements_matrix'])
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/scripts/clustering.py:39, in train_kmeans(df, rf_param, n_clusters, random_state)
#      35 def train_kmeans(
#      36     df: pd.DataFrame, rf_param: RF_PARAM_5G, n_clusters: int, random_state: int
#      37 ):
#      38     unique_pcis = extract_unique_npcis(df["measurements_matrix"])
# ---> 39     df_features, _ = create_point_matrix(
#      40         df,
#      41         unique_npcis=unique_pcis,
#      42         rf_param=rf_param,
#      43     )
#      44     kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
#      45     cluster_labels = kmeans.fit_predict(df_features)
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/scripts/matrix_operations.py:46, in create_point_matrix(df, unique_npcis, rf_param)
#      44 for _, row in df.iterrows():
#      45     measurements = row["measurements_matrix"]
# ---> 46     for _, measurement_row in measurements.iterrows():
#      47         npc_tuple = (
#      48             measurement_row["pci"],
#      49             measurement_row["beam_index"],
#      50             measurement_row["nr_arfcn"],
#      51             measurement_row["operator_id"],
#      52         )
#      54         if npc_tuple in npc_index_map:
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/venv/lib/python3.11/site-packages/pandas/core/frame.py:1554, in DataFrame.iterrows(self)
#    1552 using_cow = using_copy_on_write()
#    1553 for k, v in zip(self.index, self.values):
# -> 1554     s = klass(v, index=columns, name=k).__finalize__(self)
#    1555     if using_cow and self._mgr.is_single_block:
#    1556         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/venv/lib/python3.11/site-packages/pandas/core/series.py:586, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     583 else:
#     584     data = sanitize_array(data, index, dtype, copy)
# --> 586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#     588         data = SingleBlockManager.from_array(data, index, refs=refs)
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/venv/lib/python3.11/site-packages/pandas/_config/config.py:149, in _get_option(pat, silent)
#     146 key = _get_single_key(pat, silent)
#     148 # walk the nested dict
# --> 149 root, k = _get_root(key)
#     150 return root[k]
#
# File ~/Documents/UIO/master/thesis/dev/5G_localization/venv/lib/python3.11/site-packages/pandas/_config/config.py:636, in _get_root(key)
#     635 def _get_root(key: str) -> tuple[dict[str, Any], str]:
# --> 636     path = key.split(".")
#     637     cursor = _global_config
#     638     for p in path[:-1]:
#
# KeyboardInterrupt:
